# %% [markdown]
# **Instalando o SDK do Google**

# %%
# !pip install -q -U google-generativeai

# %% [markdown]
# Importando google generative ai e iniciando a API

# %%
import google.generativeai as genai

# Or use `os.getenv('GOOGLE_API_KEY')` to fetch an environment variable.
GOOGLE_API_KEY='AIzaSyD02AdyWZUPkRZ2vaqwDggoshUNCbHcduo'

genai.configure(api_key=GOOGLE_API_KEY)

# %% [markdown]
# Laço para listar os modelos disponíveis

# %%
for m in genai.list_models():
    if 'generateContent' in m.supported_generation_methods:
      print(m.name)
# Out:
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# models/gemini-1.5-pro-latest
# models/gemini-pro
# models/gemini-pro-vision

# %% [markdown]
# Configurando o modelo e as configurações de segurança

# %%
generation_config = {
    'candidate_count':1,
    'temperature':0.5
}

# %%
safety_settings = {
    'harassment':'Block_None',
    'hate':'Block_None',
    'sexual': 'Block_None',
    'dangerous': 'Block_None'
}

# %% [markdown]
# Inicializando o modelo

# %%
model = genai.GenerativeModel(model_name='gemini-1.0-pro',
                              generation_config=generation_config,
                              safety_settings=safety_settings)

# %%
response = model.generate_content("What is the meaning of life?")
print(response.text)
# Out:
# The meaning of life is a deeply personal and subjective question that has been pondered by philosophers, theologians, and individuals throughout history. There is no one definitive answer that will satisfy everyone, as the meaning of life can vary depending on individual values, beliefs, and experiences.
#
# **Some common perspectives on the meaning of life include:**
#
# * **Purpose-driven:** Finding a specific purpose or goal that gives your life direction and meaning. This could be a career, a hobby, a relationship, or a cause that you are passionate about.
# * **Values-based:** Living your life in accordance with your core values and beliefs. This involves identifying what is important to you and making choices that align with those values.
# * **Experiential:** Focusing on the experiences and moments that make life worthwhile. This could include spending time with loved ones, traveling, pursuing hobbies, or simply appreciating the beauty of the natural world.
# ...

# %% [markdown]
# Criando o CHAT

# %%
chat = model.start_chat(history=[])

# %% [markdown]
# Laço para manter o chat funcionando enquanto não escrever "Fim" no input.

# %% [markdown]
# Começando o chat

# %%
prompt = input('Esperando o prompt: \n')

while prompt != 'fim':
  response = chat.send_message(prompt)
  print('Resposta', response.text,'\n')
  prompt = input('Esperando o prompt \n')

# %% [markdown]
# Melhorando a visualização da conversa

# %%
import textwrap
from IPython.display import display
from IPython.display import Markdown

def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

#Imprimindo o histórico
for message in chat.history:
  display(to_markdown(f'**{message.role}**: {message.parts[0].text}'))
  print('-------------------------------------------')
